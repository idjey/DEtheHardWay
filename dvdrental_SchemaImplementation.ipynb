# %%
import configparser
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
config = configparser.ConfigParser()

# %%
config.read('clusterdvd.config')
# Out:
# []

# %%
config['POSTGRES']['PG_HOST']
# Out:
# '172.17.0.2'

# %%
db = config['POSTGRES']['PG_DB']
user = config['POSTGRES']['PG_UNAME']
passwd = config['POSTGRES']['PG_PASS']
port = config['POSTGRES']['PG_PORT']
host = config['POSTGRES']['PG_HOST']

# %% [markdown]
# Using the pandas internal read_sql method to get the data from the DB

# %%
credentials = "postgresql://{}:{}@{}:{}/{}".format(user,passwd,host,port,db)

# %%
credentials
# Out:
# 'postgresql://postgres:1234@172.17.0.2:5432/dvdrental'

# %%
filmTable = pd.read_sql("""SELECT * FROM film""",con=credentials)

# %%
filmTable.head(2)
# Out:
#    film_id             title  \
# 0      133   Chamber Italian
# 1      384  Grosse Wonderful
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
# 1            1                5         4.99      49             19.99      R
#
#               last_update     special_features  \
# 0 2013-05-26 14:50:58.951           [Trailers]
# 1 2013-05-26 14:50:58.951  [Behind the Scenes]
#
#                                             fulltext
# 0  'chamber':1 'fate':4 'husband':11 'italian':2 ...
# 1  'australia':18 'cat':8 'drama':5 'epic':4 'exp...

# %% [markdown]
# Getting the schema from the existing tables

# %%
def getSchema(tableName, credentials):
    schema = pd.read_sql("""SELECT * FROM information_schema.columns where table_name='{}'""".format(tableName),con=credentials)
    return schema

# %%
getSchema('inventory',credentials)
# Out:
#   table_catalog table_schema table_name   column_name  ordinal_position  \
# 0     dvdrental       public  inventory  inventory_id                 1
# 1     dvdrental       public  inventory       film_id                 2
# 2     dvdrental       public  inventory      store_id                 3
# 3     dvdrental       public  inventory   last_update                 4
#
#                                     column_default is_nullable  \
# 0  nextval('inventory_inventory_id_seq'::regclass)          NO
# 1                                             None          NO
# 2                                             None          NO
# 3                                            now()          NO
#
#                      data_type character_maximum_length  \
# 0                      integer                     None
# 1                     smallint                     None
# 2                     smallint                     None
# 3  timestamp without time zone                     None
#
#   character_octet_length  ...  is_identity  identity_generation  \
# 0                   None  ...           NO                 None
# 1                   None  ...           NO                 None
# 2                   None  ...           NO                 None
# 3                   None  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
#
# [4 rows x 44 columns]

# %%
def queryTable(query, credentials):
    try:
        pd.read_sql(query, credentials)
        return
    except Exception as e:
        print(e)

# %%
createDim1 = """CREATE TABLE dimdate(
                date_key integer NOT NULL PRIMARY KEY,
                date date NOT NULL,
                year smallint NOT NULL,
                quarter smallint NOT NULL,
                month smallint NOT NULL,
                day smallint NOT NULL,
                week smallint NOT NULL,
                is_weekend boolean
            )"""

# %%
createDim2 = """CREATE TABLE dimcustomer(
                customer_key SERIAL PRIMARY KEY,
                customer_id  SMALLINT NOT NULL,
                first_name VARCHAR(45) NOT NULL,
                last_name VARCHAR(45) NOT NULL,
                email VARCHAR(60),
                address VARCHAR(50) NOT NULL,
                address2 VARCHAR(50),
                district VARCHAR(50) NOT NULL,
                city VARCHAR(50) NOT NULL,
                country VARCHAR(50) NOT NULL,
                postal_code VARCHAR(10),
                phone VARCHAR(20) NOT NULL,
                active smallint NOT NULL,
                create_date timestamp NOT NULL,
                start_date date NOT NULL,
                end_date date NOT NULL
            )"""

# %%
createDim3 = """CREATE TABLE dimmovie(
                movie_key SERIAL PRIMARY KEY,
                film_id  SMALLINT NOT NULL,
                title VARCHAR(45) NOT NULL,
                description TEXT,
                release_year YEAR,
                language VARCHAR(20),
                original_language VARCHAR(20),
                rental_duration SMALLINT NOT NULL,
                length smallINT NOT NULL,
                rating VARCHAR(5) NOT NULL,
                special_features VARCHAR(60) NOT NULL
            )"""

# %%
createDim4 = """CREATE TABLE dimstore(
                store_key SERIAL PRIMARY KEY,
                store_id  SMALLINT NOT NULL,
                manager_first_name VARCHAR(45) NOT NULL,
                manager_last_name VARCHAR(45) NOT NULL,
                address VARCHAR(50) NOT NULL,
                address2 VARCHAR(50),
                district VARCHAR(20) NOT NULL,
                city VARCHAR(20) NOT NULL,
                country VARCHAR(50) NOT NULL,
                postal_code VARCHAR(10),
                start_date DATE NOT NULL,
                end_date DATE NOT NULL
                )"""

# %% [markdown]
# Making the the table

# %%
queryTable(createDim1, credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryTable(createDim2, credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryTable(createDim3, credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryTable(createDim4, credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
def queryBase(query,credentials):
    requiredTable = pd.read_sql(query,con=credentials)
    return requiredTable

# %%
query = """SELECT * FROM dimdate"""

# %%
queryBase(query,credentials).head(2)
# Out:
#    date_key        date  year  quarter  month  day  week  is_weekend
# 0     70214  2007-02-14  2007        1      2   14     7       False
# 1     70317  2007-03-17  2007        1      3   17    11        True

# %% [markdown]
# Executing insertion into the single dimdate table from payment table

# %%
insertQuery = """
        INSERT INTO dimdate (date_key, date, year, quarter, month, day, week, is_weekend)
        SELECT 
            DISTINCT(TO_CHAR(payment_date::DATE, 'yyMMDD')::integer) as date_key,
            date(payment_date) as date,
            EXTRACT(year FROM payment_date) as year,
            EXTRACT(quarter FROM payment_date) as quarter,
            EXTRACT(month FROM payment_date) as month,
            EXTRACT(day FROM payment_date) as day,
            EXTRACT(week FROM payment_date) as week,
            CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6,7) THEN true else false END;
        FROM payment;
"""

# %%
queryTable(insertQuery, credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %% [markdown]
# Multiple tables are joined and the data is extracted from it
# and dimcustomer is filled. All the below "getSchema" function calls were executed when the necessary columns where required to be checked.
#
# ### Major Benefit 1
# The benefit of writing functions that they can be called when you need to refer during the Query is written. There is no need to switch between multiple windows, or use mouse to get the data.

# %%
getSchema('country',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public    country   country_id                 1
# 1     dvdrental       public    country  last_update                 3
# 2     dvdrental       public    country      country                 2
#
#                                 column_default is_nullable  \
# 0  nextval('country_country_id_seq'::regclass)          NO
# 1                                        now()          NO
# 2                                         None          NO
#
#                      data_type  character_maximum_length  \
# 0                      integer                       NaN
# 1  timestamp without time zone                       NaN
# 2            character varying                      50.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                   200.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
#
# [3 rows x 44 columns]

# %%
getSchema('address',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public    address  last_update                 8
# 1     dvdrental       public    address      city_id                 5
# 2     dvdrental       public    address   address_id                 1
# 3     dvdrental       public    address     district                 4
# 4     dvdrental       public    address        phone                 7
# 5     dvdrental       public    address  postal_code                 6
# 6     dvdrental       public    address      address                 2
# 7     dvdrental       public    address     address2                 3
#
#                                 column_default is_nullable  \
# 0                                        now()          NO
# 1                                         None          NO
# 2  nextval('address_address_id_seq'::regclass)          NO
# 3                                         None          NO
# 4                                         None          NO
# 5                                         None         YES
# 6                                         None          NO
# 7                                         None         YES
#
#                      data_type  character_maximum_length  \
# 0  timestamp without time zone                       NaN
# 1                     smallint                       NaN
# 2                      integer                       NaN
# 3            character varying                      20.0
# 4            character varying                      20.0
# 5            character varying                      10.0
# 6            character varying                      50.0
# 7            character varying                      50.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                     NaN  ...           NO                 None
# 3                    80.0  ...           NO                 None
# 4                    80.0  ...           NO                 None
# 5                    40.0  ...           NO                 None
# 6                   200.0  ...           NO                 None
# 7                   200.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
# 4            None                None             None             None
# 5            None                None             None             None
# 6            None                None             None             None
# 7            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
# 7             NO        NEVER                  None          YES
#
# [8 rows x 44 columns]

# %%
getSchema('customer',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public   customer       active                10
# 1     dvdrental       public   customer     store_id                 2
# 2     dvdrental       public   customer  create_date                 8
# 3     dvdrental       public   customer  last_update                 9
# 4     dvdrental       public   customer  customer_id                 1
# 5     dvdrental       public   customer   address_id                 6
# 6     dvdrental       public   customer   activebool                 7
# 7     dvdrental       public   customer   first_name                 3
# 8     dvdrental       public   customer    last_name                 4
# 9     dvdrental       public   customer        email                 5
#
#                                   column_default is_nullable  \
# 0                                           None         YES
# 1                                           None          NO
# 2                            ('now'::text)::date          NO
# 3                                          now()         YES
# 4  nextval('customer_customer_id_seq'::regclass)          NO
# 5                                           None          NO
# 6                                           true          NO
# 7                                           None          NO
# 8                                           None          NO
# 9                                           None         YES
#
#                      data_type  character_maximum_length  \
# 0                      integer                       NaN
# 1                     smallint                       NaN
# 2                         date                       NaN
# 3  timestamp without time zone                       NaN
# 4                      integer                       NaN
# 5                     smallint                       NaN
# 6                      boolean                       NaN
# 7            character varying                      45.0
# 8            character varying                      45.0
# 9            character varying                      50.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                     NaN  ...           NO                 None
# 3                     NaN  ...           NO                 None
# 4                     NaN  ...           NO                 None
# 5                     NaN  ...           NO                 None
# 6                     NaN  ...           NO                 None
# 7                   180.0  ...           NO                 None
# 8                   180.0  ...           NO                 None
# 9                   200.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
# 4            None                None             None             None
# 5            None                None             None             None
# 6            None                None             None             None
# 7            None                None             None             None
# 8            None                None             None             None
# 9            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
# 7             NO        NEVER                  None          YES
# 8             NO        NEVER                  None          YES
# 9             NO        NEVER                  None          YES
#
# [10 rows x 44 columns]

# %%
getSchema('address',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public    address  last_update                 8
# 1     dvdrental       public    address      city_id                 5
# 2     dvdrental       public    address   address_id                 1
# 3     dvdrental       public    address     district                 4
# 4     dvdrental       public    address        phone                 7
# 5     dvdrental       public    address  postal_code                 6
# 6     dvdrental       public    address      address                 2
# 7     dvdrental       public    address     address2                 3
#
#                                 column_default is_nullable  \
# 0                                        now()          NO
# 1                                         None          NO
# 2  nextval('address_address_id_seq'::regclass)          NO
# 3                                         None          NO
# 4                                         None          NO
# 5                                         None         YES
# 6                                         None          NO
# 7                                         None         YES
#
#                      data_type  character_maximum_length  \
# 0  timestamp without time zone                       NaN
# 1                     smallint                       NaN
# 2                      integer                       NaN
# 3            character varying                      20.0
# 4            character varying                      20.0
# 5            character varying                      10.0
# 6            character varying                      50.0
# 7            character varying                      50.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                     NaN  ...           NO                 None
# 3                    80.0  ...           NO                 None
# 4                    80.0  ...           NO                 None
# 5                    40.0  ...           NO                 None
# 6                   200.0  ...           NO                 None
# 7                   200.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
# 4            None                None             None             None
# 5            None                None             None             None
# 6            None                None             None             None
# 7            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
# 7             NO        NEVER                  None          YES
#
# [8 rows x 44 columns]

# %%
getSchema('city',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public       city      city_id                 1
# 1     dvdrental       public       city   country_id                 3
# 2     dvdrental       public       city  last_update                 4
# 3     dvdrental       public       city         city                 2
#
#                           column_default is_nullable  \
# 0  nextval('city_city_id_seq'::regclass)          NO
# 1                                   None          NO
# 2                                  now()          NO
# 3                                   None          NO
#
#                      data_type  character_maximum_length  \
# 0                      integer                       NaN
# 1                     smallint                       NaN
# 2  timestamp without time zone                       NaN
# 3            character varying                      50.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                     NaN  ...           NO                 None
# 3                   200.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
#
# [4 rows x 44 columns]

# %%
getSchema('country',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public    country   country_id                 1
# 1     dvdrental       public    country  last_update                 3
# 2     dvdrental       public    country      country                 2
#
#                                 column_default is_nullable  \
# 0  nextval('country_country_id_seq'::regclass)          NO
# 1                                        now()          NO
# 2                                         None          NO
#
#                      data_type  character_maximum_length  \
# 0                      integer                       NaN
# 1  timestamp without time zone                       NaN
# 2            character varying                      50.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                   200.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
#
# [3 rows x 44 columns]

# %%
getSchema('dimcustomer',credentials)
# Out:
#    table_catalog table_schema   table_name   column_name  ordinal_position  \
# 0      dvdrental       public  dimcustomer  customer_key                 1
# 1      dvdrental       public  dimcustomer   customer_id                 2
# 2      dvdrental       public  dimcustomer        active                13
# 3      dvdrental       public  dimcustomer   create_date                14
# 4      dvdrental       public  dimcustomer    start_date                15
# 5      dvdrental       public  dimcustomer      end_date                16
# 6      dvdrental       public  dimcustomer      address2                 7
# 7      dvdrental       public  dimcustomer      district                 8
# 8      dvdrental       public  dimcustomer          city                 9
# 9      dvdrental       public  dimcustomer       country                10
# 10     dvdrental       public  dimcustomer   postal_code                11
# 11     dvdrental       public  dimcustomer         phone                12
# 12     dvdrental       public  dimcustomer    first_name                 3
# 13     dvdrental       public  dimcustomer     last_name                 4
# 14     dvdrental       public  dimcustomer         email                 5
# 15     dvdrental       public  dimcustomer       address                 6
#
#                                        column_default is_nullable  \
# 0   nextval('dimcustomer_customer_key_seq'::regclass)          NO
# 1                                                None          NO
# 2                                                None          NO
# 3                                                None          NO
# 4                                                None          NO
# 5                                                None          NO
# 6                                                None          NO
# 7                                                None          NO
# 8                                                None          NO
# 9                                                None          NO
# 10                                               None         YES
# 11                                               None          NO
# 12                                               None          NO
# 13                                               None          NO
# 14                                               None         YES
# 15                                               None          NO
#
#                       data_type  character_maximum_length  \
# 0                       integer                       NaN
# 1                      smallint                       NaN
# 2                      smallint                       NaN
# 3   timestamp without time zone                       NaN
# 4                          date                       NaN
# 5                          date                       NaN
# 6             character varying                      50.0
# 7             character varying                      20.0
# 8             character varying                      20.0
# 9             character varying                      50.0
# 10            character varying                      10.0
# 11            character varying                      20.0
# 12            character varying                      45.0
# 13            character varying                      45.0
# 14            character varying                      60.0
# 15            character varying                      50.0
#
#     character_octet_length  ...  is_identity  identity_generation  \
# 0                      NaN  ...           NO                 None
# 1                      NaN  ...           NO                 None
# 2                      NaN  ...           NO                 None
# 3                      NaN  ...           NO                 None
# 4                      NaN  ...           NO                 None
# 5                      NaN  ...           NO                 None
# 6                    200.0  ...           NO                 None
# 7                     80.0  ...           NO                 None
# 8                     80.0  ...           NO                 None
# 9                    200.0  ...           NO                 None
# 10                    40.0  ...           NO                 None
# 11                    80.0  ...           NO                 None
# 12                   180.0  ...           NO                 None
# 13                   180.0  ...           NO                 None
# 14                   240.0  ...           NO                 None
# 15                   200.0  ...           NO                 None
#
#     identity_start  identity_increment identity_maximum identity_minimum  \
# 0             None                None             None             None
# 1             None                None             None             None
# 2             None                None             None             None
# 3             None                None             None             None
# 4             None                None             None             None
# 5             None                None             None             None
# 6             None                None             None             None
# 7             None                None             None             None
# 8             None                None             None             None
# 9             None                None             None             None
# 10            None                None             None             None
# 11            None                None             None             None
# 12            None                None             None             None
# 13            None                None             None             None
# 14            None                None             None             None
# 15            None                None             None             None
#
#    identity_cycle is_generated generation_expression is_updatable
# 0              NO        NEVER                  None          YES
# 1              NO        NEVER                  None          YES
# 2              NO        NEVER                  None          YES
# 3              NO        NEVER                  None          YES
# 4              NO        NEVER                  None          YES
# 5              NO        NEVER                  None          YES
# 6              NO        NEVER                  None          YES
# 7              NO        NEVER                  None          YES
# 8              NO        NEVER                  None          YES
# 9              NO        NEVER                  None          YES
# 10             NO        NEVER                  None          YES
# 11             NO        NEVER                  None          YES
# 12             NO        NEVER                  None          YES
# 13             NO        NEVER                  None          YES
# 14             NO        NEVER                  None          YES
# 15             NO        NEVER                  None          YES
#
# [16 rows x 44 columns]

# %% [markdown]
# ### Major Benefit 2:
# When doing the join and need to refer the table columns, the functions written inside the jupyter environment can be used for querying the tables

# %%
checkQuery_error = """
        SELECT c.customer_id as customer_key,
                c.customer_id, c.first_name, c.last_name, c.email,
                a.address, a.address2, a.district, ci.city, co.country, 
                postal_code, a.phone, c.active, c.create_date,now() as start_date,
                now() as end_date
        FROM customer AS c
        JOIN address ON c.address_id = a.address_id
        JOIN city ON a.city_id = ci.city_id
        JOIN country ON ci.country_id = co.country_id;
"""
#The tables are not having aliases... Observe

# %%
checkQuery = """
        SELECT c.customer_id as customer_key,
                c.customer_id, c.first_name, c.last_name, c.email,
                a.address, a.address2, a.district, ci.city, co.country, 
                postal_code, a.phone, c.active, c.create_date,now() as start_date,
                now() as end_date
        FROM customer AS c
        JOIN address AS a ON c.address_id = a.address_id
        JOIN city AS ci ON a.city_id = ci.city_id
        JOIN country AS co ON ci.country_id = co.country_id;
"""
#this executes

# %% [markdown]
# ### Major Benefit 3:
# After writing complicated select queries they can be wrong due to various reasons. If required the "Wrong" queries can be retained as a reference...

# %%
queryBase(checkQuery,credentials).head(2)
# Out:
#    customer_key  customer_id first_name last_name  \
# 0           524          524      Jared       Ely
# 1             1            1       Mary     Smith
#
#                            email                  address address2   district  \
# 0   jared.ely@sakilacustomer.org  1003 Qinhuangdao Street           West Java
# 1  mary.smith@sakilacustomer.org           1913 Hanoi Way            Nagasaki
#
#          city    country postal_code        phone  active create_date  \
# 0  Purwakarta  Indonesia       25972  35533115997       1  2006-02-14
# 1      Sasebo      Japan       35200  28303384290       1  2006-02-14
#
#                         start_date                         end_date
# 0 2022-11-01 11:05:07.699618+00:00 2022-11-01 11:05:07.699618+00:00
# 1 2022-11-01 11:05:07.699618+00:00 2022-11-01 11:05:07.699618+00:00

# %%
insertCustomer = """
            INSERT INTO dimcustomer(customer_key,customer_id,first_name,
            last_name,email,address,address2,district,city,country,
            postal_code,phone,active,create_date,start_date,end_date)
            SELECT c.customer_id as customer_key,
                c.customer_id, c.first_name, c.last_name, c.email,
                a.address, a.address2, a.district, ci.city, co.country, 
                postal_code, a.phone, c.active, c.create_date,now() as start_date,
                now() as end_date
            FROM customer AS c
            JOIN address AS a ON c.address_id = a.address_id
            JOIN city AS ci ON a.city_id = ci.city_id
            JOIN country AS co ON ci.country_id = co.country_id;
"""

# %% [markdown]
# #### Inserting data into dimcustomer table and consecutively checking contents

# %%
queryTable(insertCustomer,credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryCheckdimCustomer = """SELECT * FROM dimcustomer"""
queryBase(queryCheckdimCustomer,credentials).head(2)
# Out:
#    customer_key  customer_id first_name last_name  \
# 0           524          524      Jared       Ely
# 1             1            1       Mary     Smith
#
#                            email                  address address2   district  \
# 0   jared.ely@sakilacustomer.org  1003 Qinhuangdao Street           West Java
# 1  mary.smith@sakilacustomer.org           1913 Hanoi Way            Nagasaki
#
#          city    country postal_code        phone  active create_date  \
# 0  Purwakarta  Indonesia       25972  35533115997       1  2006-02-14
# 1      Sasebo      Japan       35200  28303384290       1  2006-02-14
#
#    start_date    end_date
# 0  2022-11-01  2022-11-01
# 1  2022-11-01  2022-11-01

# %% [markdown]
# Referring the tables that we are planning to join, here referring inventory table

# %%
getSchema('dimstore',credentials)
# Out:
#    table_catalog table_schema table_name         column_name  \
# 0      dvdrental       public   dimstore           store_key
# 1      dvdrental       public   dimstore            store_id
# 2      dvdrental       public   dimstore          start_date
# 3      dvdrental       public   dimstore            end_date
# 4      dvdrental       public   dimstore             address
# 5      dvdrental       public   dimstore            address2
# 6      dvdrental       public   dimstore            district
# 7      dvdrental       public   dimstore                city
# 8      dvdrental       public   dimstore             country
# 9      dvdrental       public   dimstore         postal_code
# 10     dvdrental       public   dimstore  manager_first_name
# 11     dvdrental       public   dimstore   manager_last_name
#
#     ordinal_position                               column_default is_nullable  \
# 0                  1  nextval('dimstore_store_key_seq'::regclass)          NO
# 1                  2                                         None          NO
# 2                 11                                         None          NO
# 3                 12                                         None          NO
# 4                  5                                         None          NO
# 5                  6                                         None         YES
# 6                  7                                         None          NO
# 7                  8                                         None          NO
# 8                  9                                         None          NO
# 9                 10                                         None         YES
# 10                 3                                         None          NO
# 11                 4                                         None          NO
#
#             data_type  character_maximum_length  character_octet_length  ...  \
# 0             integer                       NaN                     NaN  ...
# 1            smallint                       NaN                     NaN  ...
# 2                date                       NaN                     NaN  ...
# 3                date                       NaN                     NaN  ...
# 4   character varying                      50.0                   200.0  ...
# 5   character varying                      50.0                   200.0  ...
# 6   character varying                      20.0                    80.0  ...
# 7   character varying                      20.0                    80.0  ...
# 8   character varying                      50.0                   200.0  ...
# 9   character varying                      10.0                    40.0  ...
# 10  character varying                      45.0                   180.0  ...
# 11  character varying                      45.0                   180.0  ...
#
#     is_identity  identity_generation  identity_start  identity_increment  \
# 0            NO                 None            None                None
# 1            NO                 None            None                None
# 2            NO                 None            None                None
# 3            NO                 None            None                None
# 4            NO                 None            None                None
# 5            NO                 None            None                None
# 6            NO                 None            None                None
# 7            NO                 None            None                None
# 8            NO                 None            None                None
# 9            NO                 None            None                None
# 10           NO                 None            None                None
# 11           NO                 None            None                None
#
#    identity_maximum identity_minimum identity_cycle is_generated  \
# 0              None             None             NO        NEVER
# 1              None             None             NO        NEVER
# 2              None             None             NO        NEVER
# 3              None             None             NO        NEVER
# 4              None             None             NO        NEVER
# 5              None             None             NO        NEVER
# 6              None             None             NO        NEVER
# 7              None             None             NO        NEVER
# 8              None             None             NO        NEVER
# 9              None             None             NO        NEVER
# 10             None             None             NO        NEVER
# 11             None             None             NO        NEVER
#
#    generation_expression is_updatable
# 0                   None          YES
# 1                   None          YES
# 2                   None          YES
# 3                   None          YES
# 4                   None          YES
# 5                   None          YES
# 6                   None          YES
# 7                   None          YES
# 8                   None          YES
# 9                   None          YES
# 10                  None          YES
# 11                  None          YES
#
# [12 rows x 44 columns]

# %%
getSchema('store',credentials)
# Out:
#   table_catalog table_schema table_name       column_name  ordinal_position  \
# 0     dvdrental       public      store          store_id                 1
# 1     dvdrental       public      store  manager_staff_id                 2
# 2     dvdrental       public      store        address_id                 3
# 3     dvdrental       public      store       last_update                 4
#
#                             column_default is_nullable  \
# 0  nextval('store_store_id_seq'::regclass)          NO
# 1                                     None          NO
# 2                                     None          NO
# 3                                    now()          NO
#
#                      data_type character_maximum_length  \
# 0                      integer                     None
# 1                     smallint                     None
# 2                     smallint                     None
# 3  timestamp without time zone                     None
#
#   character_octet_length  ...  is_identity  identity_generation  \
# 0                   None  ...           NO                 None
# 1                   None  ...           NO                 None
# 2                   None  ...           NO                 None
# 3                   None  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
#
# [4 rows x 44 columns]

# %%
getSchema('staff',credentials)
# Out:
#    table_catalog table_schema table_name  column_name  ordinal_position  \
# 0      dvdrental       public      staff      picture                11
# 1      dvdrental       public      staff   address_id                 4
# 2      dvdrental       public      staff     store_id                 6
# 3      dvdrental       public      staff       active                 7
# 4      dvdrental       public      staff  last_update                10
# 5      dvdrental       public      staff     staff_id                 1
# 6      dvdrental       public      staff   first_name                 2
# 7      dvdrental       public      staff    last_name                 3
# 8      dvdrental       public      staff     password                 9
# 9      dvdrental       public      staff        email                 5
# 10     dvdrental       public      staff     username                 8
#
#                              column_default is_nullable  \
# 0                                      None         YES
# 1                                      None          NO
# 2                                      None          NO
# 3                                      true          NO
# 4                                     now()          NO
# 5   nextval('staff_staff_id_seq'::regclass)          NO
# 6                                      None          NO
# 7                                      None          NO
# 8                                      None         YES
# 9                                      None         YES
# 10                                     None          NO
#
#                       data_type  character_maximum_length  \
# 0                         bytea                       NaN
# 1                      smallint                       NaN
# 2                      smallint                       NaN
# 3                       boolean                       NaN
# 4   timestamp without time zone                       NaN
# 5                       integer                       NaN
# 6             character varying                      45.0
# 7             character varying                      45.0
# 8             character varying                      40.0
# 9             character varying                      50.0
# 10            character varying                      16.0
#
#     character_octet_length  ...  is_identity  identity_generation  \
# 0                      NaN  ...           NO                 None
# 1                      NaN  ...           NO                 None
# 2                      NaN  ...           NO                 None
# 3                      NaN  ...           NO                 None
# 4                      NaN  ...           NO                 None
# 5                      NaN  ...           NO                 None
# 6                    180.0  ...           NO                 None
# 7                    180.0  ...           NO                 None
# 8                    160.0  ...           NO                 None
# 9                    200.0  ...           NO                 None
# 10                    64.0  ...           NO                 None
#
#     identity_start  identity_increment identity_maximum identity_minimum  \
# 0             None                None             None             None
# 1             None                None             None             None
# 2             None                None             None             None
# 3             None                None             None             None
# 4             None                None             None             None
# 5             None                None             None             None
# 6             None                None             None             None
# 7             None                None             None             None
# 8             None                None             None             None
# 9             None                None             None             None
# 10            None                None             None             None
#
#    identity_cycle is_generated generation_expression is_updatable
# 0              NO        NEVER                  None          YES
# 1              NO        NEVER                  None          YES
# 2              NO        NEVER                  None          YES
# 3              NO        NEVER                  None          YES
# 4              NO        NEVER                  None          YES
# 5              NO        NEVER                  None          YES
# 6              NO        NEVER                  None          YES
# 7              NO        NEVER                  None          YES
# 8              NO        NEVER                  None          YES
# 9              NO        NEVER                  None          YES
# 10             NO        NEVER                  None          YES
#
# [11 rows x 44 columns]

# %% [markdown]
# #### Inserting data into dimstore table and consecutively checking contents

# %%
insertStore = """
        INSERT INTO dimstore(store_key,store_id,start_date,end_date,
            address,address2,district,city,country,
            postal_code,manager_first_name,manager_last_name)
            SELECT s.store_id as store_key,
                s.store_id, 
                now() as start_date,
                now() as end_date,
                a.address, 
                a.address2, 
                a.district, 
                ci.city, 
                co.country, 
                postal_code, 
                st.first_name as manager_first_name, 
                st.last_name as manager_last_name 
            FROM store AS s
            JOIN staff AS st ON s.manager_staff_id = st.staff_id
            JOIN address AS a ON st.address_id = a.address_id
            JOIN city AS ci ON a.city_id = ci.city_id
            JOIN country AS co ON ci.country_id = co.country_id;
"""
#before FROM there comma should not be there

# %%
queryTable(insertStore,credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryCheckdimStore = """SELECT * FROM dimstore"""
queryBase(queryCheckdimStore,credentials).head(2)
# Out:
#    store_key  store_id manager_first_name manager_last_name  \
# 0          1         1               Mike           Hillyer
# 1          2         2                Jon          Stephens
#
#                 address address2 district        city    country postal_code  \
# 0     23 Workhaven Lane     None  Alberta  Lethbridge     Canada
# 1  1411 Lillydale Drive     None      QLD   Woodridge  Australia
#
#    start_date    end_date
# 0  2022-11-01  2022-11-01
# 1  2022-11-01  2022-11-01

# %% [markdown]
# Insert the factsales table, this contains the important step of references

# %%
getSchema('film',credentials)
# Out:
#    table_catalog table_schema table_name       column_name  ordinal_position  \
# 0      dvdrental       public       film          fulltext                13
# 1      dvdrental       public       film            rating                10
# 2      dvdrental       public       film       last_update                11
# 3      dvdrental       public       film           film_id                 1
# 4      dvdrental       public       film      release_year                 4
# 5      dvdrental       public       film       language_id                 5
# 6      dvdrental       public       film   rental_duration                 6
# 7      dvdrental       public       film       rental_rate                 7
# 8      dvdrental       public       film            length                 8
# 9      dvdrental       public       film  replacement_cost                 9
# 10     dvdrental       public       film             title                 2
# 11     dvdrental       public       film       description                 3
# 12     dvdrental       public       film  special_features                12
#
#                            column_default is_nullable  \
# 0                                    None          NO
# 1                        'G'::mpaa_rating         YES
# 2                                   now()          NO
# 3   nextval('film_film_id_seq'::regclass)          NO
# 4                                    None         YES
# 5                                    None          NO
# 6                                       3          NO
# 7                                    4.99          NO
# 8                                    None         YES
# 9                                   19.99          NO
# 10                                   None          NO
# 11                                   None         YES
# 12                                   None         YES
#
#                       data_type  character_maximum_length  \
# 0                      tsvector                       NaN
# 1                  USER-DEFINED                       NaN
# 2   timestamp without time zone                       NaN
# 3                       integer                       NaN
# 4                       integer                       NaN
# 5                      smallint                       NaN
# 6                      smallint                       NaN
# 7                       numeric                       NaN
# 8                      smallint                       NaN
# 9                       numeric                       NaN
# 10            character varying                     255.0
# 11                         text                       NaN
# 12                        ARRAY                       NaN
#
#     character_octet_length  ...  is_identity  identity_generation  \
# 0                      NaN  ...           NO                 None
# 1                      NaN  ...           NO                 None
# 2                      NaN  ...           NO                 None
# 3                      NaN  ...           NO                 None
# 4                      NaN  ...           NO                 None
# 5                      NaN  ...           NO                 None
# 6                      NaN  ...           NO                 None
# 7                      NaN  ...           NO                 None
# 8                      NaN  ...           NO                 None
# 9                      NaN  ...           NO                 None
# 10            1.020000e+03  ...           NO                 None
# 11            1.073742e+09  ...           NO                 None
# 12                     NaN  ...           NO                 None
#
#     identity_start  identity_increment identity_maximum identity_minimum  \
# 0             None                None             None             None
# 1             None                None             None             None
# 2             None                None             None             None
# 3             None                None             None             None
# 4             None                None             None             None
# 5             None                None             None             None
# 6             None                None             None             None
# 7             None                None             None             None
# 8             None                None             None             None
# 9             None                None             None             None
# 10            None                None             None             None
# 11            None                None             None             None
# 12            None                None             None             None
#
#    identity_cycle is_generated generation_expression is_updatable
# 0              NO        NEVER                  None          YES
# 1              NO        NEVER                  None          YES
# 2              NO        NEVER                  None          YES
# 3              NO        NEVER                  None          YES
# 4              NO        NEVER                  None          YES
# 5              NO        NEVER                  None          YES
# 6              NO        NEVER                  None          YES
# 7              NO        NEVER                  None          YES
# 8              NO        NEVER                  None          YES
# 9              NO        NEVER                  None          YES
# 10             NO        NEVER                  None          YES
# 11             NO        NEVER                  None          YES
# 12             NO        NEVER                  None          YES
#
# [13 rows x 44 columns]

# %%
getSchema('language',credentials)
# Out:
#   table_catalog table_schema table_name  column_name  ordinal_position  \
# 0     dvdrental       public   language  language_id                 1
# 1     dvdrental       public   language  last_update                 3
# 2     dvdrental       public   language         name                 2
#
#                                   column_default is_nullable  \
# 0  nextval('language_language_id_seq'::regclass)          NO
# 1                                          now()          NO
# 2                                           None          NO
#
#                      data_type  character_maximum_length  \
# 0                      integer                       NaN
# 1  timestamp without time zone                       NaN
# 2                    character                      20.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2                    80.0  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
#
# [3 rows x 44 columns]

# %%
insertMovie = f"""
        INSERT INTO dimmovie(movie_key, film_id, title, description, 
        release_year , language, original_language ,rental_duration ,
        length, rating, special_features)
        SELECT 
            f.film_id as movie_key,
            f.film_id,
            f.title,
            f.description,
            f.release_year,
            l.last_update as language,
            l.name as original_language,
            f.rental_duration,
            f.length,
            f.rating,
            f.special_features
        FROM film as f
        JOIN language as l ON f.language_id = l.language_id
"""

# %%
queryTable(insertMovie,credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryCheckMovie = """SELECT * FROM dimmovie"""
queryBase(queryCheckMovie,credentials).head(2)
#There is mistake in language column. The last_update date is populated instead of language name.
# Out:
#    movie_key  film_id             title  \
# 0        133      133   Chamber Italian
# 1        384      384  Grosse Wonderful
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
#
#               language original_language  rental_duration  length rating  \
# 0  2006-02-15 10:02:19           English                7     117  NC-17
# 1  2006-02-15 10:02:19           English                5      49      R
#
#         special_features
# 0             {Trailers}
# 1  {"Behind the Scenes"}

# %% [markdown]
# ### Preparing the final factsales

# %%
queryBase('SELECT * FROM dimdate', credentials).head(2)
# Out:
#    date_key        date  year  quarter  month  day  week  is_weekend
# 0     70214  2007-02-14  2007        1      2   14     7       False
# 1     70317  2007-03-17  2007        1      3   17    11        True

# %%
getSchema('dimdate',credentials)
# Out:
#   table_catalog table_schema table_name column_name  ordinal_position  \
# 0     dvdrental       public    dimdate    date_key                 1
# 1     dvdrental       public    dimdate        date                 2
# 2     dvdrental       public    dimdate        year                 3
# 3     dvdrental       public    dimdate     quarter                 4
# 4     dvdrental       public    dimdate       month                 5
# 5     dvdrental       public    dimdate         day                 6
# 6     dvdrental       public    dimdate        week                 7
# 7     dvdrental       public    dimdate  is_weekend                 8
#
#   column_default is_nullable data_type character_maximum_length  \
# 0           None          NO   integer                     None
# 1           None          NO      date                     None
# 2           None          NO  smallint                     None
# 3           None          NO  smallint                     None
# 4           None          NO  smallint                     None
# 5           None          NO  smallint                     None
# 6           None          NO  smallint                     None
# 7           None         YES   boolean                     None
#
#   character_octet_length  ...  is_identity  identity_generation  \
# 0                   None  ...           NO                 None
# 1                   None  ...           NO                 None
# 2                   None  ...           NO                 None
# 3                   None  ...           NO                 None
# 4                   None  ...           NO                 None
# 5                   None  ...           NO                 None
# 6                   None  ...           NO                 None
# 7                   None  ...           NO                 None
#
#    identity_start  identity_increment identity_maximum identity_minimum  \
# 0            None                None             None             None
# 1            None                None             None             None
# 2            None                None             None             None
# 3            None                None             None             None
# 4            None                None             None             None
# 5            None                None             None             None
# 6            None                None             None             None
# 7            None                None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
# 7             NO        NEVER                  None          YES
#
# [8 rows x 44 columns]

# %%
createfactSales = """CREATE TABLE factsales(
                    sales_key SERIAL PRIMARY KEY,
                    date_key integer REFERENCES dimdate(date_key),
                    customer_key integer REFERENCES dimcustomer(customer_key),
                    movie_key integer REFERENCES dimmovie(movie_key),
                    store_key integer REFERENCES dimstore(store_key),
                    sales_amount numeric)"""

# %%
#Inserting the factsales table and checking it
queryTable(createfactSales, credentials)
getSchema('factsales',credentials)
# Out:
# This result object does not return rows. It has been closed automatically.
#   table_catalog table_schema table_name   column_name  ordinal_position  \
# 0     dvdrental       public  factsales     sales_key                 1
# 1     dvdrental       public  factsales      date_key                 2
# 2     dvdrental       public  factsales  customer_key                 3
# 3     dvdrental       public  factsales     movie_key                 4
# 4     dvdrental       public  factsales     store_key                 5
# 5     dvdrental       public  factsales  sales_amount                 6
#
#                                  column_default is_nullable data_type  \
# 0  nextval('factsales_sales_key_seq'::regclass)          NO   integer
# 1                                          None         YES   integer
# 2                                          None         YES   integer
# 3                                          None         YES   integer
# 4                                          None         YES   integer
# 5                                          None         YES   numeric
#
#   character_maximum_length character_octet_length  ...  is_identity  \
# 0                     None                   None  ...           NO
# 1                     None                   None  ...           NO
# 2                     None                   None  ...           NO
# 3                     None                   None  ...           NO
# 4                     None                   None  ...           NO
# 5                     None                   None  ...           NO
#
#    identity_generation  identity_start identity_increment identity_maximum  \
# 0                 None            None               None             None
# 1                 None            None               None             None
# 2                 None            None               None             None
# 3                 None            None               None             None
# 4                 None            None               None             None
# 5                 None            None               None             None
#
#   identity_minimum identity_cycle is_generated generation_expression  \
# 0             None             NO        NEVER                  None
# 1             None             NO        NEVER                  None
# 2             None             NO        NEVER                  None
# 3             None             NO        NEVER                  None
# 4             None             NO        NEVER                  None
# 5             None             NO        NEVER                  None
#
#   is_updatable
# 0          YES
# 1          YES
# 2          YES
# 3          YES
# 4          YES
# 5          YES
#
# [6 rows x 44 columns]

# %%
insertSale = """INSERT INTO factsales(date_key, customer_key, movie_key,
                store_key, sales_amount)
                SELECT
                    DISTINCT(TO_CHAR(payment_date::DATE, 'yyMMDD')::integer) as date_key,
                    p.customer_id as customer_key,
                    i.film_id as movie_key,
                    i.store_id as store_key,
                    p.amount as sales_amount
                FROM payment as p
                JOIN rental r ON p.rental_id = r.rental_id
                JOIN inventory i ON r.inventory_id = i.inventory_id;"""

#The distinct keyword is required for the datekey. We are creating it

# %%
queryTable(insertSale,credentials)
# Out:
# This result object does not return rows. It has been closed automatically.

# %%
queryBase("""SELECT * FROM factsales""", credentials)
# Out:
#        sales_key  date_key  customer_key  movie_key  store_key  sales_amount
# 0              1     70428           177        149          2          1.99
# 1              2     70412           246        518          2          4.99
# 2              3     70409            43        608          1          4.99
# 3              4     70409           174        267          1          4.99
# 4              5     70218            86        767          2          4.99
# ...          ...       ...           ...        ...        ...           ...
# 14591      14592     70302           375        621          1          5.99
# 14592      14593     70301           192        122          1          0.99
# 14593      14594     70317           303        899          1          0.99
# 14594      14595     70318           247        827          2          7.99
# 14595      14596     70319           118        115          2          6.99
#
# [14596 rows x 6 columns]

# %% [markdown]
# ### Running the final query

# %%
finalQuery = """SELECT dm.title, dd.month, dc.city, SUM(sales_amount) as revenue
                FROM factsales as fs
                JOIN dimmovie as dm ON fs.movie_key = dm.movie_key
                JOIN dimdate as dd ON fs.date_key = dd.date_key
                JOIN dimcustomer as dc ON fs.customer_key = dc.customer_key
                GROUP BY (dm.title, dd.month, dc.city)"""

# %%
queryBase(finalQuery,credentials)
# Out:
#                      title  month                    city  revenue
# 0           French Holiday      2                 Bayugan     4.99
# 1           Jekyll Frogmen      4      Varanasi (Benares)     5.99
# 2        Intentions Empire      4              Pjatigorsk     4.99
# 3      League Hellfighters      3  Coacalco de Berriozbal     4.99
# 4           Grit Clockwork      3                   Bchar     3.99
# ...                    ...    ...                     ...      ...
# 14535         Beneath Rush      3                  Namibe     0.99
# 14536       Liaisons Sweet      3                 Tonghae     7.99
# 14537      Sun Confessions      4                  Ashdod     3.99
# 14538       Name Detective      3                   Adoni     4.99
# 14539    Movie Shakespeare      4                 Yingkou     6.99
#
# [14540 rows x 4 columns]

# %%
orderQuery = """SELECT dm.title, dd.month, dc.city, SUM(sales_amount) as revenue
                FROM factsales as fs
                JOIN dimmovie as dm ON fs.movie_key = dm.movie_key
                JOIN dimdate as dd ON fs.date_key = dd.date_key
                JOIN dimcustomer as dc ON fs.customer_key = dc.customer_key
                GROUP BY (dm.title, dd.month, dc.city)
                ORDER BY revenue DESC"""

# %%
queryBase(orderQuery,credentials)
# Out:
#                       title  month           city  revenue
# 0         Caribbean Liberty      4         Ibirit    16.98
# 1              Eagles Panky      3         Datong    16.98
# 2                 Lust Lock      4  Coatzacoalcos    15.98
# 3            Innocent Usual      2       Valparai    13.98
# 4      Breakfast Goldfinger      4            Ife    13.98
# ...                     ...    ...            ...      ...
# 14535         Minority Kiss      5     Battambang     0.00
# 14536       State Wasteland      5       Erlangen     0.00
# 14537          Trouble Date      5       Changhwa     0.00
# 14538        Lawless Vision      5     Nagareyama     0.00
# 14539      Titanic Boondock      5     Santo Andr     0.00
#
# [14540 rows x 4 columns]
